# %%
# !pip install --quiet "numpy<2" opencv-python torch torchvision captum

# %%
# # Siamese exp
# python run_siamese_experiment.py --model_name grey --process lung_seg --train_source chestxray14 --bsz 64 --run 1 -q

# # Basice SupCon 
# python run_supcon_experiment.py --model_name grey --process lung_seg --train_source chestxray14 --loss_type supcon --temperature 0.1 --bsz 256 --run 1 -q

# # Hierarchical/Hybrid SupCon
# python run_supcon_experiment.py --model_name grey --process lung_seg --train_source chestxray14 --loss_type hierarchical --alpha 0.5 --beta 0.5 --temperature 0.1 --bsz 256 --run 1 -q

# %%
# !python run_supcon_experiment_v2.py \
--model_name rad \
--process crop \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101
# Out:
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  6.16it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 2478/2478 [00:16<00:00, 149.71it/s]
# Cached 2478 images
# Total pairs: 1239
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 420
#   normal (idx=0): 819
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  9.21it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 1062/1062 [00:06<00:00, 155.38it/s]
# Cached 1062 images
# Total pairs: 531
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 180
#   normal (idx=0): 351
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00, 58.26it/s]
# Caching base images into RAM...
# Caching: 100%|███████████████████████████████| 144/144 [00:00<00:00, 153.61it/s]
# Cached 144 images
# Total pairs: 72
# ...

# %%
# !python run_supcon_experiment_v2.py \
--model_name rgb \
--process lung_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101
# Out:
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  5.77it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 2478/2478 [00:13<00:00, 180.65it/s]
# Cached 2478 images
# Total pairs: 1239
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 420
#   normal (idx=0): 819
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  9.13it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 1062/1062 [00:06<00:00, 173.79it/s]
# Cached 1062 images
# Total pairs: 531
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 180
#   normal (idx=0): 351
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00, 78.42it/s]
# Caching base images into RAM...
# Caching: 100%|███████████████████████████████| 144/144 [00:00<00:00, 174.33it/s]
# Cached 144 images
# Total pairs: 72
# ...

# %%
# !python run_supcon_experiment_v2.py \
--model_name grey \
--process lung_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101

# %%
# !python run_supcon_experiment_v2.py \
--model_name single \
--process lung_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101

# %%
python run_supcon_experiment_v2.py \
--model_name single \
--process arch_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101

# %%
python run_supcon_experiment_v2.py \
--model_name rgb \
--process crop \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101 && python run_supcon_experiment_v2.py \
--model_name grey \
--process crop \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101 && python run_supcon_experiment_v2.py \
--model_name single \
--process crop \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101

# %%
# !python run_supcon_experiment_v2.py \
--model_name rad \
--process arch_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 128 \
--lr 0.0003 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 101
# Out:
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  5.87it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 2478/2478 [00:15<00:00, 159.93it/s]
# Cached 2478 images
# Total pairs: 1239
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 420
#   normal (idx=0): 819
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  8.07it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 1062/1062 [00:06<00:00, 160.66it/s]
# Cached 1062 images
# Total pairs: 531
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 180
#   normal (idx=0): 351
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00, 57.23it/s]
# Caching base images into RAM...
# Caching: 100%|███████████████████████████████| 144/144 [00:00<00:00, 158.89it/s]
# Cached 144 images
# Total pairs: 72
# ...

# %%
# !python run_supcon_experiment.py \
--model_name rad \
--process arch_seg \
--train_source chestxray14 \
--loss_type hierarchical \
--alpha 0.7 \
--beta 0.3 \
--temperature 0.1 \
--margin 1.0 \
--distance cosine \
--bsz 256 \
--lr 0.0001 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561
# Out:
#   Cell In[5], line 1
#     python run_supcon_experiment.py \
#            ^
# SyntaxError: invalid syntax

# %%
python run_supcon_experiment_v2.py \
--model_name rad \
--process lung_seg \
--train_source chestxray14 \
--loss_type hierarchical \
--alpha 0.7 \
--beta 0.3 \
--temperature 0.1 \
--margin 1.0 \
--distance cosine \
--bsz 256 \
--lr 0.0001 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561 \
--epochs 200

# %%
# !python run_supcon_experiment.py \
--model_name rad \
--process arch_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 256 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561 -q
# Out:
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00,  5.59it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 2478/2478 [00:23<00:00, 105.13it/s]
# Cached 2478 images
# Total pairs: 1239
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 420
#   normal (idx=0): 819
# Loading dataset: 100%|████████████████████████████| 2/2 [00:00<00:00, 13.78it/s]
# Caching base images into RAM...
# Caching: 100%|█████████████████████████████| 1062/1062 [00:10<00:00, 102.57it/s]
# Cached 1062 images
# Total pairs: 531
# Number of classes: 2
# Class mapping: {'nodule': 1, 'normal': 0}
#
# Pairs per class:
#   nodule (idx=1): 180
#   normal (idx=0): 351
# Loading dataset: 100%|███████████████████████████| 2/2 [00:00<00:00, 103.47it/s]
# Caching base images into RAM...
# Caching: 100%|███████████████████████████████| 144/144 [00:01<00:00, 101.89it/s]
# Cached 144 images
# Total pairs: 72
# ...

# %%
# !python run_supcon_experiment.py \
--model_name rad \
--process lung_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 256 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561 -q

# %%
# !python run_supcon_experiment.py \
--model_name grey \
--process crop \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 256 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561 -q

# %%
# !python run_supcon_experiment.py \
--model_name grey \
--process arch_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 256 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561 -q

# %%
# !python run_supcon_experiment.py \
--model_name grey \
--process lung_seg \
--train_source chestxray14 \
--loss_type supcon \
--temperature 0.1 \
--bsz 256 \
--cache_in_ram \
--symmetrical_transforms \
--workers 10 \
--run 2561 -q
